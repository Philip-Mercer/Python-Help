# %%
# pip install sqlalchemy

# %%
# pip install lxml

# %%
# pip install html5lib

# %%
# pip install BeautifulSoup4

# %% [markdown]
# <h1/> Data Input and Output
# <h3>
#     <li/>CSV
#     <li/>Excel
#     <li/>HTML
#     <li/>SQL
# </h3>

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\philm\\Documents\\Work\\Training\\Python\\Data Science'

# %%
pd.read_csv('example.csv')
# Out:
#    txn_id     type          isin client_id            trade_date  \
# 0  txn001  StockIn  US5949181045      MSFT  2021-09-01T10:00:00Z
# 1  txn002  StockIn  US5949181045      MSFT  2021-09-01T10:00:00Z
#
#         settlement_date  quantity  price  total_consideration currency  \
# 0  2021-09-02T10:00:00Z      1000    300               300000      USD
# 1  2021-09-02T10:00:00Z       500    310               165000      USD
#
#                    portfolio
# 0  EquityPortfolioForPnLCalc
# 1  EquityPortfolioForPnLCalc

# %%
df = pd.read_csv('example.csv')

# %%
df
# Out:
#    txn_id     type          isin client_id            trade_date  \
# 0  txn001  StockIn  US5949181045      MSFT  2021-09-01T10:00:00Z
# 1  txn002  StockIn  US5949181045      MSFT  2021-09-01T10:00:00Z
#
#         settlement_date  quantity  price  total_consideration currency  \
# 0  2021-09-02T10:00:00Z      1000    300               300000      USD
# 1  2021-09-02T10:00:00Z       500    310               165000      USD
#
#                    portfolio
# 0  EquityPortfolioForPnLCalc
# 1  EquityPortfolioForPnLCalc

# %%
df.to_csv('MY_OUTPUT.csv', index=False)

# %%
pd.read_excel('Excel_Samples.xlsx', sheet_name='Sheet1')
# Out:
#      pclass  survived                                             name  \
# 0       1st         1                     Allen, Miss Elisabeth Walton
# 1       1st         0                      Allison, Miss Helen Loraine
# 2       1st         0              Allison, Mr Hudson Joshua Creighton
# 3       1st         0  Allison, Mrs Hudson J.C. (Bessie Waldo Daniels)
# 4       1st         1                    Allison, Master Hudson Trevor
# ...     ...       ...                                              ...
# 1308    3rd         0                               Zakarian, Mr Artun
# 1309    3rd         0                           Zakarian, Mr Maprieder
# 1310    3rd         0                                  Zenn, Mr Philip
# 1311    3rd         0                                    Zievens, Rene
# 1312    3rd         0                                   Zimmerman, Leo
#
#           age     embarked                        home.dest room      ticket  \
# ...

# %%
df.to_excel('Example_Sample2.xlsx', sheet_name='Fred')

# %%
# data = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html') # Expired SSL Token

# data = pd.read_html('https://www.york.ac.uk/teaching/cws/wws/webpage1.html') # 403 - Forbidden

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:') # creates an in memory SQ-Lite database to interract with

# %%
df
# Out:
#    txn_id     type          isin client_id            trade_date  \
# 0  txn001  StockIn  US5949181045      MSFT  2021-09-01T10:00:00Z
# 1  txn002  StockIn  US5949181045      MSFT  2021-09-01T10:00:00Z
#
#         settlement_date  quantity  price  total_consideration currency  \
# 0  2021-09-02T10:00:00Z      1000    300               300000      USD
# 1  2021-09-02T10:00:00Z       500    310               165000      USD
#
#                    portfolio
# 0  EquityPortfolioForPnLCalc
# 1  EquityPortfolioForPnLCalc

# %%
df.to_sql('my_trades', engine)
# Out:
# 2

# %%
sqldf = pd.read_sql('my_trades', con=engine)

# %%
sqldf
# Out:
#    index  txn_id     type          isin client_id            trade_date  \
# 0      0  txn001  StockIn  US5949181045      MSFT  2021-09-01T10:00:00Z
# 1      1  txn002  StockIn  US5949181045      MSFT  2021-09-01T10:00:00Z
#
#         settlement_date  quantity  price  total_consideration currency  \
# 0  2021-09-02T10:00:00Z      1000    300               300000      USD
# 1  2021-09-02T10:00:00Z       500    310               165000      USD
#
#                    portfolio
# 0  EquityPortfolioForPnLCalc
# 1  EquityPortfolioForPnLCalc
